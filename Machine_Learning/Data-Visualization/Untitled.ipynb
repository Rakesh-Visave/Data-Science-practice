# %%
import matplotlib

# %%
    fig, ax = plt.subplots(figsize=(12, 5))
    ax.plot(historical_data['ds'], historical_data['yhat'], label='Historical Data', color='blue')
    ax.plot(forecast_data['ds'], forecast_data['yhat'], label='Forecasted Data', color='red')
    plt.title(f'Forecast for the next {days} days from {model_start_date.strftime("%Y-%m-%d")} ({model_name})', fontsize=14)
    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.legend()
