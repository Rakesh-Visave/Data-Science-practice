# %%
import pickle
import numpy as np

# %%
ohe_sex = pickle.load(open('models/ohe_sex.pkl','rb'))
ohe_embarked = pickle.load(open('models/ohe_embarked.pkl','rb'))
clf = pickle.load(open('models/clf.pkl','rb'))

# %%
# Pclass/gender/age/SibSp/Parch/Fare/Embarked
test_input = np.array([1, 'female', 38.0, 1, 0, 71.2833, 'C'],dtype=object).reshape(1,7)

# %%
test_input
# Out:
# array([[1, 'female', 38.0, 1, 0, 71.2833, 'C']], dtype=object)

# %%
test_input_sex = ohe_sex.transform(test_input[:,1].reshape(1,1))
# Out:
# C:\Users\msi_katana_2\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
test_input_sex
# Out:
# array([[1., 0.]])

# %%
test_input_embarked = ohe_embarked.transform(test_input[:,-1].reshape(1,1))

# %%
test_input_embarked
# Out:
# array([[1., 0., 0.]])

# %%
test_input_age = test_input[:,2].reshape(1,1)

# %%
test_input_transformed = np.concatenate((test_input[:,[0,3,4,5]],test_input_age,test_input_sex,test_input_embarked),axis=1)

# %%
test_input_transformed.shape
# Out:
# (1, 10)

# %%
# clf.predict(test_input_transformed)

# %%
predictions = clf.predict(test_input_transformed)
interpret_predictions(predictions)

def interpret_predictions(predictions):
    for value in predictions:
        if value == 0:
            print("Not Served")
        elif value == 1:
            print("Served")
# Out:
# Served
