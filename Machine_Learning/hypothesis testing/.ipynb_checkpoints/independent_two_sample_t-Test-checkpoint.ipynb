# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('train.csv').drop(columns=['Survived'])
test = pd.read_csv('test.csv')

# %%
final_df = pd.concat([train,test]).sample(1309)

# %%
pop_male = final_df[final_df['Sex'] == 'male']['Age'].dropna()
pop_female = final_df[final_df['Sex'] == 'female']['Age'].dropna()

# %%
pop_female
# Out:
# 554    22.0
# 220    30.0
# 483    63.0
# 830    15.0
# 77     55.0
#        ...
# 479     2.0
# 567    29.0
# 400    30.0
# 520    30.0
# 443    28.0
# Name: Age, Length: 388, dtype: float64

# %%
sample_male = pop_male.sample(25)
sample_female = pop_female.sample(25)

alpha = 0.05

# %%
# H0 - Mean age of male and female are similar
# H1 - Mean age of male is higher than female

# %%
pop_male.mean()
# Out:
# 30.58522796352584

# %%
pop_female.mean()
# Out:
# 28.68708762886598

# %%
# check for noramlity

from scipy.stats import shapiro

shapiro_male = shapiro(sample_male)
shapiro_female = shapiro(sample_female)

print("Shapiro-Wilk test for Male sample:", shapiro_male)
print("Shapiro-Wilk test for Female Sample:", shapiro_female)
# Out:
# Shapiro-Wilk test for desktop users: ShapiroResult(statistic=0.9801501710997518, pvalue=0.8880684634214466)
# Shapiro-Wilk test for mobile users: ShapiroResult(statistic=0.9653149047295463, pvalue=0.5300510125506814)

# %%
# levene is used to check the variance of two group is equal or not
# pvalue > alpha then equal
from scipy.stats import levene

# Perform Levene's test
levene_test = levene(sample_male, sample_female)
print(levene_test)
# Out:
# LeveneResult(statistic=0.590792838874681, pvalue=0.44587815320877566)

# %%
import scipy.stats as stats

t_statistic, p_value = stats.ttest_ind(sample_male, sample_female)

print("t-statistic:", t_statistic)
print("p-value:", p_value/2)
# Out:
# t-statistic: 1.5654682860964864
# p-value: 0.06202139429373079

# %%
alpha = 0.05

if p_value < alpha:
    print("Reject the null hypothesis.")
else:
    print("Fail to reject the null hypothesis.")
# Out:
# Fail to reject the null hypothesis.
